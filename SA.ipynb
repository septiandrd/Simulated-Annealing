# %%
import random,math

def generateSolusi() :
    x1 = random.uniform(-1,1)
    x2 = random.uniform(-1,1)
    solusi = [x1,x2]
    return solusi

def modify(x1,x2) :
    x1 += random.uniform(-1,1)
    x2 += random.uniform(-1,1)
    solusi = [x1, x2]
    return solusi

def hitungEnergi(x1,x2) :
    # energi = ( (4-(2.1*(x1**2))+((x1**4)/3)) * (x1**2) ) + (x1*x2) + ( (-4+4*(x2**2)) * (x2**2) )
    energi = (((2.1*(x1**2))+((x2**4)/3)) * (x1**2) ) + (-x1*x2) + ( (4*(x2**2)) * (x2**2) )
    return energi

# %%
if __name__ == '__main__':

    iterasi = 0
    maxIterasi = 500000
    t0 = 500000
    tmin = 1*10**-100
    # tmin = 0.001
    alpha = 0.995

    bestSolusi = generateSolusi()
    bestEnergi = hitungEnergi(bestSolusi[0],bestSolusi[1])
    x = []
    y = []

    while (t0>tmin and iterasi!=maxIterasi) :
        x.append(1)
        y.append(hitungEnergi(nextSolusi[0],nextSolusi[1]))
        nextSolusi = generateSolusi()
        nextEnergi = hitungEnergi(nextSolusi[0],nextSolusi[1])
        dE = bestEnergi-nextEnergi
        if (dE>0) :
            bestSolusi = nextSolusi
            bestEnergi = nextEnergi
            print("Iterasi ke-",iterasi, ", suhu %.2f" % t0, "derajat")
            print("Solusi Terbaik : x1 = %.8f" % bestSolusi[0], " ; x2 = %.8f" % bestSolusi[1], " dengan hasil %.8f" % bestEnergi, "\n")
        else :
            p = random.random()
            pSolusiBaru = math.exp((bestEnergi-nextEnergi)/t0)

            if pSolusiBaru > p :
                bestSolusi = nextSolusi
                bestEnergi = nextEnergi

        t0 *= alpha
        iterasi += 1
# Out:
# Iterasi ke- 0 , suhu 500000.00 derajat
# Solusi Terbaik : x1 = 0.13834677  ; x2 = -0.75468277  dengan hasil 1.40477770
#
# Iterasi ke- 1 , suhu 497500.00 derajat
# Solusi Terbaik : x1 = 0.18290239  ; x2 = 0.61989075  dengan hasil 0.48125419
#
# Iterasi ke- 2 , suhu 495012.50 derajat
# Solusi Terbaik : x1 = -0.08017979  ; x2 = 0.42148435  dengan hasil 0.16018569
#
# Iterasi ke- 4 , suhu 490074.75 derajat
# Solusi Terbaik : x1 = 0.74923043  ; x2 = 0.78039466  dengan hasil 1.63003698
#
# Iterasi ke- 6 , suhu 485186.25 derajat
# Solusi Terbaik : x1 = 0.54815926  ; x2 = 0.30530781  dengan hasil 0.05787098
#
# Iterasi ke- 9 , suhu 477944.79 derajat
# Solusi Terbaik : x1 = 0.16049054  ; x2 = -0.29961553  dengan hasil 0.08178209
#
# Iterasi ke- 12 , suhu 470811.40 derajat
# Solusi Terbaik : x1 = -0.26393919  ; x2 = -0.05798190  dengan hasil -0.00506680
#
# Iterasi ke- 15 , suhu 463784.48 derajat
# Solusi Terbaik : x1 = -0.75454854  ; x2 = -0.72523594  dengan hasil 1.29256073
#
# Iterasi ke- 16 , suhu 461465.56 derajat
# Solusi Terbaik : x1 = -0.12852862  ; x2 = 0.68881264  dengan hasil 0.99080481
#
# Iterasi ke- 17 , suhu 459158.23 derajat
# Solusi Terbaik : x1 = 0.72860876  ; x2 = 0.15949890  dengan hasil 0.47832080
#
# Iterasi ke- 18 , suhu 456862.44 derajat
# Solusi Terbaik : x1 = -0.40369183  ; x2 = 0.08114048  dengan hasil 0.08870386
#
# Iterasi ke- 21 , suhu 450043.71 derajat
# Solusi Terbaik : x1 = 0.45304940  ; x2 = -0.54346984  dengan hasil 0.68960726
#
# Iterasi ke- 22 , suhu 447793.50 derajat
# Solusi Terbaik : x1 = 0.47160441  ; x2 = 0.64761321  dengan hasil 0.51509812
#
# Iterasi ke- 25 , suhu 441110.12 derajat
# Solusi Terbaik : x1 = 0.72951719  ; x2 = 0.36439612  dengan hasil 0.40260848
#
# Iterasi ke- 28 , suhu 434526.50 derajat
# Solusi Terbaik : x1 = 0.62956447  ; x2 = -0.32236896  dengan hasil 0.57747614
#
# Iterasi ke- 30 , suhu 430192.10 derajat
# Solusi Terbaik : x1 = 0.38542117  ; x2 = -0.33546265  dengan hasil 0.22691876
#
# Iterasi ke- 33 , suhu 423771.43 derajat
# Solusi Terbaik : x1 = 0.40418025  ; x2 = 0.72312043  dengan hasil 0.87237182
#
# Iterasi ke- 34 , suhu 421652.57 derajat
# Solusi Terbaik : x1 = 0.24757136  ; x2 = -0.10051348  dengan hasil 0.03318360
#
# Iterasi ke- 37 , suhu 415359.35 derajat
# Solusi Terbaik : x1 = 0.12570107  ; x2 = -0.19275267  dengan hasil 0.03028234
#
# Iterasi ke- 40 , suhu 409160.06 derajat
# Solusi Terbaik : x1 = 0.32521905  ; x2 = 0.68554090  dengan hasil 0.69180149
#
# Iterasi ke- 43 , suhu 403053.30 derajat
# Solusi Terbaik : x1 = -0.28847662  ; x2 = -0.40934421  dengan hasil 0.00954489
#
# Iterasi ke- 45 , suhu 399032.84 derajat
# Solusi Terbaik : x1 = 0.76242468  ; x2 = 0.46696236  dengan hasil 0.55296860
#
# Iterasi ke- 47 , suhu 395052.49 derajat
# Solusi Terbaik : x1 = 0.24336773  ; x2 = -0.47799609  dengan hasil 0.33353904
#
# Iterasi ke- 50 , suhu 389156.28 derajat
# Solusi Terbaik : x1 = 0.30972469  ; x2 = 0.76441543  dengan hasil 1.15925556
#
# Iterasi ke- 51 , suhu 387210.50 derajat
# Solusi Terbaik : x1 = 0.30746294  ; x2 = -0.60678901  dengan hasil 0.75186784
#
# Iterasi ke- 53 , suhu 383348.07 derajat
# Solusi Terbaik : x1 = -0.38181739  ; x2 = -0.37195970  dengan hasil -0.01989158
#
# Iterasi ke- 56 , suhu 377626.55 derajat
# Solusi Terbaik : x1 = -0.68981547  ; x2 = 0.89909684  dengan hasil 3.81324312
#
# Iterasi ke- 57 , suhu 375738.42 derajat
# Solusi Terbaik : x1 = -0.74078097  ; x2 = 0.14236458  dengan hasil 0.73955985
#
# Iterasi ke- 59 , suhu 371990.43 derajat
# Solusi Terbaik : x1 = -0.23984725  ; x2 = -0.39328895  dengan hasil 0.00877798
#
# Iterasi ke- 62 , suhu 366438.43 derajat
# Solusi Terbaik : x1 = -0.70464551  ; x2 = -0.16232195  dengan hasil 0.40624091
#
# Iterasi ke- 64 , suhu 362783.20 derajat
# Solusi Terbaik : x1 = 0.62284269  ; x2 = 0.70084241  dengan hasil 0.87574747
#
# Iterasi ke- 65 , suhu 360969.29 derajat
# Solusi Terbaik : x1 = -0.32480307  ; x2 = 0.49752223  dengan hasil 0.43220476
#
# Iterasi ke- 67 , suhu 357368.62 derajat
# Solusi Terbaik : x1 = -0.42957505  ; x2 = 0.38822998  dengan hasil 0.33055183
#
# Iterasi ke- 69 , suhu 353803.87 derajat
# Solusi Terbaik : x1 = -0.35615368  ; x2 = -0.59016286  dengan hasil 0.31395877
#
# Iterasi ke- 70 , suhu 352034.85 derajat
# Solusi Terbaik : x1 = -0.02694611  ; x2 = -0.41035417  dengan hasil 0.10237203
#
# Iterasi ke- 74 , suhu 345046.78 derajat
# Solusi Terbaik : x1 = 0.02021020  ; x2 = 0.93231823  dengan hasil 3.00341566
#
# Iterasi ke- 75 , suhu 343321.55 derajat
# Solusi Terbaik : x1 = -0.71576282  ; x2 = -0.52913363  dengan hasil 0.49939626
#
# Iterasi ke- 77 , suhu 339896.91 derajat
# Solusi Terbaik : x1 = -0.33623727  ; x2 = -0.55239265  dengan hasil 0.21705099
#
# Iterasi ke- 80 , suhu 334823.91 derajat
# Solusi Terbaik : x1 = -0.86265872  ; x2 = 0.31421398  dengan hasil 1.47545655
#
# Iterasi ke- 81 , suhu 333149.79 derajat
# Solusi Terbaik : x1 = -0.00637329  ; x2 = -0.38772095  dengan hasil 0.08792273
#
# Iterasi ke- 82 , suhu 331484.04 derajat
# Solusi Terbaik : x1 = -0.07721571  ; x2 = -0.05541385  dengan hasil -0.00416643
#
# Iterasi ke- 84 , suhu 328177.49 derajat
# Solusi Terbaik : x1 = -0.67486944  ; x2 = 0.01869950  dengan hasil 0.44823073
#
# Iterasi ke- 86 , suhu 324903.92 derajat
# Solusi Terbaik : x1 = -0.67987458  ; x2 = 0.14125270  dengan hasil 0.54636556
#
# Iterasi ke- 87 , suhu 323279.40 derajat
# Solusi Terbaik : x1 = 0.51676825  ; x2 = -0.40697707  dengan hasil 0.47225082
#
# Iterasi ke- 88 , suhu 321663.00 derajat
# Solusi Terbaik : x1 = 0.15813437  ; x2 = -0.40484970  dengan hasil 0.17301490
#
# Iterasi ke- 91 , suhu 316862.14 derajat
# Solusi Terbaik : x1 = -0.75490847  ; x2 = 0.74144252  dengan hasil 2.50799200
#
# Iterasi ke- 92 , suhu 315277.83 derajat
# Solusi Terbaik : x1 = -0.92008234  ; x2 = -0.69441283  dengan hasil 1.86176469
#
# Iterasi ke- 93 , suhu 313701.44 derajat
# Solusi Terbaik : x1 = -0.41732856  ; x2 = 0.38446284  dengan hasil 0.31280774
#
# Iterasi ke- 97 , suhu 307474.31 derajat
# Solusi Terbaik : x1 = -0.52825259  ; x2 = -0.63637684  dengan hasil 0.49863374
#
# Iterasi ke- 99 , suhu 304407.25 derajat
# Solusi Terbaik : x1 = 0.05697848  ; x2 = -0.32676372  dengan hasil 0.06425617
#
# Iterasi ke- 102 , suhu 299863.94 derajat
# Solusi Terbaik : x1 = -0.88351165  ; x2 = -0.94773437  dengan hasil 3.87922258
#
# Iterasi ke- 103 , suhu 298364.62 derajat
# Solusi Terbaik : x1 = -0.92631857  ; x2 = 0.43327051  dengan hasil 2.09856871
#
# Iterasi ke- 104 , suhu 296872.80 derajat
# Solusi Terbaik : x1 = -0.61334670  ; x2 = 0.18402334  dengan hasil 0.41479749
#
# Iterasi ke- 107 , suhu 292441.93 derajat
# Solusi Terbaik : x1 = 0.49587402  ; x2 = -0.02079518  dengan hasil 0.13728361
#
# Iterasi ke- 109 , suhu 289524.82 derajat
# Solusi Terbaik : x1 = -0.82802187  ; x2 = -0.24642340  dengan hasil 0.79870628
#
# Iterasi ke- 111 , suhu 286636.81 derajat
# Solusi Terbaik : x1 = 0.31329243  ; x2 = 0.70552810  dengan hasil 0.79840050
#
# Iterasi ke- 112 , suhu 285203.63 derajat
# Solusi Terbaik : x1 = 0.24201069  ; x2 = 0.24652613  dengan hasil -0.03761165
#
# Iterasi ke- 114 , suhu 282358.72 derajat
# Solusi Terbaik : x1 = -0.42350574  ; x2 = 0.48922807  dengan hasil 0.50731300
#
# Iterasi ke- 115 , suhu 280946.93 derajat
# Solusi Terbaik : x1 = -0.13873325  ; x2 = -0.36865152  dengan hasil 0.02363173
#
# Iterasi ke- 116 , suhu 279542.19 derajat
# Solusi Terbaik : x1 = -0.16476681  ; x2 = -0.02205920  dengan hasil -0.00208593
#
# Iterasi ke- 118 , suhu 276753.76 derajat
# Solusi Terbaik : x1 = 0.28553417  ; x2 = 0.61516945  dengan hasil 0.41504655
#
# Iterasi ke- 120 , suhu 273993.14 derajat
# Solusi Terbaik : x1 = -0.39575565  ; x2 = -0.29878401  dengan hasil -0.03443722
#
# Iterasi ke- 125 , suhu 267211.47 derajat
# Solusi Terbaik : x1 = 0.97219437  ; x2 = -0.08186306  dengan hasil 1.95577570
#
# Iterasi ke- 128 , suhu 263223.31 derajat
# Solusi Terbaik : x1 = -0.39851783  ; x2 = 0.43148984  dengan hasil 0.36541625
#
# Iterasi ke- 130 , suhu 260597.65 derajat
# Solusi Terbaik : x1 = -0.23699558  ; x2 = -0.70073072  dengan hasil 0.80948533
#
# Iterasi ke- 131 , suhu 259294.67 derajat
# Solusi Terbaik : x1 = -0.26010019  ; x2 = 0.48669151  dengan hasil 0.36189209
#
# Iterasi ke- 133 , suhu 256708.20 derajat
# Solusi Terbaik : x1 = -0.12608381  ; x2 = -0.65456459  dengan hasil 0.65326755
#
# Iterasi ke- 134 , suhu 255424.66 derajat
# Solusi Terbaik : x1 = -0.14644587  ; x2 = -0.55530938  dengan hasil 0.30068746
#
# Iterasi ke- 135 , suhu 254147.54 derajat
# Solusi Terbaik : x1 = -0.22358526  ; x2 = 0.45467409  dengan hasil 0.27856528
#
# Iterasi ke- 138 , suhu 250354.35 derajat
# Solusi Terbaik : x1 = 0.47900817  ; x2 = -0.13284839  dengan hasil 0.17546340
#
# Iterasi ke- 140 , suhu 247857.07 derajat
# Solusi Terbaik : x1 = -0.92132788  ; x2 = -0.01408683  dengan hasil 1.50015124
#
# Iterasi ke- 142 , suhu 245384.69 derajat
# Solusi Terbaik : x1 = 0.13238739  ; x2 = 0.59027224  dengan hasil 0.40879933
#
# Iterasi ke- 143 , suhu 244157.77 derajat
# Solusi Terbaik : x1 = 0.28975077  ; x2 = 0.20240890  dengan hasil -0.03708530
#
# Iterasi ke- 145 , suhu 241722.30 derajat
# Solusi Terbaik : x1 = 0.12529339  ; x2 = 0.08044356  dengan hasil -0.00939380
#
# Iterasi ke- 147 , suhu 239311.12 derajat
# Solusi Terbaik : x1 = 0.54537175  ; x2 = -0.29275124  dengan hasil 0.37554279
#
# Iterasi ke- 149 , suhu 236923.99 derajat
# Solusi Terbaik : x1 = 0.29103010  ; x2 = -0.77824458  dengan hasil 1.71923283
#
# Iterasi ke- 150 , suhu 235739.37 derajat
# Solusi Terbaik : x1 = 0.88372890  ; x2 = 0.03869060  dengan hasil 1.24665942
#
# Iterasi ke- 153 , suhu 232220.93 derajat
# Solusi Terbaik : x1 = 0.30377647  ; x2 = -0.77155793  dengan hasil 1.68070103
#
# Iterasi ke- 154 , suhu 231059.82 derajat
# Solusi Terbaik : x1 = 0.37075114  ; x2 = 0.34932979  dengan hasil -0.02958759
#
# Iterasi ke- 156 , suhu 228755.00 derajat
# Solusi Terbaik : x1 = 0.79141803  ; x2 = 0.55241451  dengan hasil 0.77858689
#
# Iterasi ke- 158 , suhu 226473.17 derajat
# Solusi Terbaik : x1 = -0.35960122  ; x2 = -0.44964332  dengan hasil 0.03869116
#
# Iterasi ke- 160 , suhu 224214.10 derajat
# Solusi Terbaik : x1 = 0.40919893  ; x2 = 0.26069244  dengan hasil -0.02906417
#
# Iterasi ke- 162 , suhu 221977.57 derajat
# Solusi Terbaik : x1 = 0.73534733  ; x2 = -0.51508413  dengan hasil 1.28704405
#
# Iterasi ke- 164 , suhu 219763.34 derajat
# Solusi Terbaik : x1 = -0.19411128  ; x2 = 0.54695856  dengan hasil 0.46827192
#
# Iterasi ke- 165 , suhu 218664.52 derajat
# Solusi Terbaik : x1 = -0.37695269  ; x2 = -0.59847900  dengan hasil 0.33604162
#
# Iterasi ke- 168 , suhu 215400.93 derajat
# Solusi Terbaik : x1 = -0.99948064  ; x2 = -0.60863042  dengan hasil 2.08189513
#
# Iterasi ke- 169 , suhu 214323.92 derajat
# Solusi Terbaik : x1 = 0.51091530  ; x2 = 0.39747672  dengan hasil 0.04202725
#
# Iterasi ke- 171 , suhu 212186.04 derajat
# Solusi Terbaik : x1 = 0.90270603  ; x2 = 0.07396264  dengan hasil 1.32781683
#
# Iterasi ke- 172 , suhu 211125.11 derajat
# Solusi Terbaik : x1 = 0.57625346  ; x2 = -0.43862929  dengan hasil 0.63648858
#
# Iterasi ke- 173 , suhu 210069.49 derajat
# Solusi Terbaik : x1 = 0.33084826  ; x2 = -0.13727872  dengan hasil 0.07201338
#
# Iterasi ke- 177 , suhu 205899.50 derajat
# Solusi Terbaik : x1 = -0.20196963  ; x2 = -0.18159815  dengan hasil -0.02881803
#
# Iterasi ke- 179 , suhu 203845.65 derajat
# Solusi Terbaik : x1 = -0.53428621  ; x2 = -0.91962335  dengan hasil 2.60872169
#
# Iterasi ke- 181 , suhu 201812.29 derajat
# Solusi Terbaik : x1 = -0.39849712  ; x2 = -0.85678331  dengan hasil 1.89553506
#
# Iterasi ke- 182 , suhu 200803.23 derajat
# Solusi Terbaik : x1 = 0.79180779  ; x2 = -0.26518802  dengan hasil 1.05625817
#
# Iterasi ke- 183 , suhu 199799.22 derajat
# Solusi Terbaik : x1 = -0.56207886  ; x2 = 0.04474564  dengan hasil 0.23477526
#
# Iterasi ke- 186 , suhu 196817.19 derajat
# Solusi Terbaik : x1 = -0.05489947  ; x2 = -0.20618430  dengan hasil -0.00406945
#
# Iterasi ke- 188 , suhu 194853.94 derajat
# Solusi Terbaik : x1 = 0.25026067  ; x2 = -0.44732754  dengan hasil 0.28118492
#
# Iterasi ke- 190 , suhu 192910.27 derajat
# Solusi Terbaik : x1 = 0.42366400  ; x2 = -0.01443862  dengan hasil 0.07377318
#
# Iterasi ke- 193 , suhu 190031.06 derajat
# Solusi Terbaik : x1 = 0.12103851  ; x2 = -0.16210872  dengan hasil 0.02283789
#
# Iterasi ke- 195 , suhu 188135.50 derajat
# Solusi Terbaik : x1 = -0.19433664  ; x2 = 0.09843582  dengan hasil 0.02250171
#
# Iterasi ke- 198 , suhu 185327.55 derajat
# Solusi Terbaik : x1 = -0.49776444  ; x2 = 0.44530284  dengan hasil 0.51110479
#
# Iterasi ke- 199 , suhu 184400.92 derajat
# Solusi Terbaik : x1 = -0.42719482  ; x2 = 0.13829434
#   dengan hasil 0.13050360
#
# Iterasi ke- 202 , suhu 181648.71 derajat
# Solusi Terbaik : x1 = 0.68398798  ; x2 = -0.15217041  dengan hasil 0.56594621
#
# Iterasi ke- 204 , suhu 179836.76 derajat
# Solusi Terbaik : x1 = 0.64076648  ; x2 = 0.15510844  dengan hasil 0.25701856
#
# Iterasi ke- 206 , suhu 178042.89 derajat
# Solusi Terbaik : x1 = -0.03407310  ; x2 = 0.55215618  dengan hasil 0.39065105
#
# Iterasi ke- 209 , suhu 175385.58 derajat
# Solusi Terbaik : x1 = 0.36631890  ; x2 = -0.11139513  dengan hasil 0.07924329
#
# Iterasi ke- 212 , suhu 172767.93 derajat
# Solusi Terbaik : x1 = -0.66975664  ; x2 = -0.30170272  dengan hasil 0.25487239
#
# Iterasi ke- 214 , suhu 171044.57 derajat
# Solusi Terbaik : x1 = 0.09005195  ; x2 = -0.04154328  dengan hasil 0.00389108
#
# Iterasi ke- 215 , suhu 170189.34 derajat
# Solusi Terbaik : x1 = -0.07279259  ; x2 = -0.19032047  dengan hasil -0.00854454
#
# Iterasi ke- 217 , suhu 168491.71 derajat
# Solusi Terbaik : x1 = 0.17678552  ; x2 = -0.31618702  dengan hasil 0.09803199
#
# Iterasi ke- 218 , suhu 167649.25 derajat
# Solusi Terbaik : x1 = -0.39581066  ; x2 = 0.11307073  dengan hasil 0.09695991
#
# Iterasi ke- 220 , suhu 165976.95 derajat
# Solusi Terbaik : x1 = -0.32796470  ; x2 = 0.83360522  dengan hasil 2.24653286
#
# Iterasi ke- 222 , suhu 164321.33 derajat
# Solusi Terbaik : x1 = 0.71033622  ; x2 = -0.39315512  dengan hasil 0.91351637
#
# Iterasi ke- 224 , suhu 162682.22 derajat
# Solusi Terbaik : x1 = -0.26366127  ; x2 = -0.28830649  dengan hasil -0.03807043
#
# Iterasi ke- 228 , suhu 159452.90 derajat
# Solusi Terbaik : x1 = -0.32588510  ; x2 = 0.38956218  dengan hasil 0.24357582
#
# Iterasi ke- 230 , suhu 157862.35 derajat
# Solusi Terbaik : x1 = 0.14100193  ; x2 = 0.23175709  dengan hasil -0.02028936
#
# Iterasi ke- 232 , suhu 156287.68 derajat
# Solusi Terbaik : x1 = 0.90931506  ; x2 = 0.83253917  dengan hasil 2.73278418
#
# Iterasi ke- 233 , suhu 155506.24 derajat
# Solusi Terbaik : x1 = 0.64725379  ; x2 = -0.08158072  dengan hasil 0.42155485
#
# Iterasi ke- 235 , suhu 153955.06 derajat
# Solusi Terbaik : x1 = 0.30982527  ; x2 = 0.60211219  dengan hasil 0.36274459
#
# Iterasi ke- 236 , suhu 153185.29 derajat
# Solusi Terbaik : x1 = 0.09882825  ; x2 = 0.37351023  dengan hasil 0.04120237
#
# Iterasi ke- 240 , suhu 150144.48 derajat
# Solusi Terbaik : x1 = -0.74494912  ; x2 = 0.31075026  dengan hasil 0.91725191
#
# Iterasi ke- 241 , suhu 149393.76 derajat
# Solusi Terbaik : x1 = 0.27146012  ; x2 = 0.22506358  dengan hasil -0.03936597
#
# Iterasi ke- 243 , suhu 147903.56 derajat
# Solusi Terbaik : x1 = -0.23977796  ; x2 = 0.20974991  dengan hasil 0.06501430
#
# Iterasi ke- 246 , suhu 145696.08 derajat
# Solusi Terbaik : x1 = -0.01162702  ; x2 = -0.33674573  dengan hasil 0.04752141
#
# Iterasi ke- 248 , suhu 144242.76 derajat
# Solusi Terbaik : x1 = -0.04758331  ; x2 = 0.09243596  dengan hasil 0.00470126
#
# Iterasi ke- 250 , suhu 142803.94 derajat
# Solusi Terbaik : x1 = 0.09802332  ; x2 = -0.15545683  dengan hasil 0.01777029
#
# Iterasi ke- 252 , suhu 141379.47 derajat
# Solusi Terbaik : x1 = 0.72937114  ; x2 = 0.38597275  dengan hasil 0.40550306
#
# Iterasi ke- 256 , suhu 138573.02 derajat
# Solusi Terbaik : x1 = 0.77557533  ; x2 = 0.01069791  dengan hasil 0.75153094
#
# Iterasi ke- 257 , suhu 137880.15 derajat
# Solusi Terbaik : x1 = -0.54200686  ; x2 = -0.17592176  dengan hasil 0.08980770
#
# Iterasi ke- 259 , suhu 136504.80 derajat
# Solusi Terbaik : x1 = 0.86964916  ; x2 = 0.35359168  dengan hasil 0.96011259
#
# Iterasi ke- 262 , suhu 134467.45 derajat
# Solusi Terbaik : x1 = -0.79212044  ; x2 = -0.53007780  dengan hasil 0.73920091
#
# Iterasi ke- 264 , suhu 133126.13 derajat
# Solusi Terbaik : x1 = -0.78167871  ; x2 = -0.70198691  dengan hasil 1.25611172
#
# Iterasi ke- 266 , suhu 131798.20 derajat
# Solusi Terbaik : x1 = 0.37300559  ; x2 = 0.75380044  dengan hasil 1.06592764
#
# Iterasi ke- 267 , suhu 131139.21 derajat
# Solusi Terbaik : x1 = -0.57674501  ; x2 = -0.20236666  dengan hasil 0.12253677
#
# Iterasi ke- 270 , suhu 129181.94 derajat
# Solusi Terbaik : x1 = -0.48911575  ; x2 = 0.28268365  dengan hasil 0.28450603
#
# Iterasi ke- 272 , suhu 127893.35 derajat
# Solusi Terbaik : x1 = 0.97594042  ; x2 = -0.26693284  dengan hasil 2.18750738
#
# Iterasi ke- 273 , suhu 127253.88 derajat
# Solusi Terbaik : x1 = -0.69277950  ; x2 = 0.69720489  dengan hasil 1.94968890
#
# Iterasi ke- 274 , suhu 126617.61 derajat
# Solusi Terbaik : x1 = 0.74624527  ; x2 = 0.16982616  dengan hasil 0.52799651
#
# Iterasi ke- 275 , suhu 125984.53 derajat
# Solusi Terbaik : x1 = -0.24885132  ; x2 = -0.27429898  dengan hasil -0.03744522
#
# Iterasi ke- 277 , suhu 124727.83 derajat
# Solusi Terbaik : x1 = -0.87802238  ; x2 = -0.47208463  dengan hasil 1.04501360
#
# Iterasi ke- 278 , suhu 124104.19 derajat
# Solusi Terbaik : x1 = -0.21537316  ; x2 = 0.42654090  dengan hasil 0.22930017
#
# Iterasi ke- 280 , suhu 122866.25 derajat
# Solusi Terbaik : x1 = 0.05754330  ; x2 = 0.11771621  dengan hasil -0.00598247
#
# Iterasi ke- 283 , suhu 121032.46 derajat
# Solusi Terbaik : x1 = 0.31230505  ; x2 = -0.06902225  dengan hasil 0.04162475
#
# Iterasi ke- 284 , suhu 120427.30 derajat
# Solusi Terbaik : x1 = 0.05705910  ; x2 = 0.19278522  dengan hasil -0.00545110
#
# Iterasi ke- 287 , suhu 118629.90 derajat
# Solusi Terbaik : x1 = 0.46724712  ; x2 = -0.27726267  dengan hasil 0.25371255
#
# Iterasi ke- 291 , suhu 116275.04 derajat
# Solusi Terbaik : x1 = 0.71267913  ; x2 = 0.14009909  dengan hasil 0.44350621
#
# Iterasi ke- 294 , suhu 114539.62 derajat
# Solusi Terbaik : x1 = -0.11151167  ; x2 = 0.04590847  dengan hasil 0.00546183
#
# Iterasi ke- 297 , suhu 112830.10 derajat
# Solusi Terbaik : x1 = 0.24214648  ; x2 = 0.32416210  dengan hasil -0.02689086
#
# Iterasi ke- 300 , suhu 111146.10 derajat
# Solusi Terbaik : x1 = -0.02724238  ; x2 = -0.34597875  dengan hasil 0.04789302
#
# Iterasi ke- 302 , suhu 110037.42 derajat
# Solusi Terbaik : x1 = 0.34969087  ; x2 = -0.39608953  dengan hasil 0.26936812
#
# Iterasi ke- 304 , suhu 108939.79 derajat
# Solusi Terbaik : x1 = -0.48779104  ; x2 = -0.80997227  dengan hasil 1.47956552
#
# Iterasi ke- 305 , suhu 108395.10 derajat
# Solusi Terbaik : x1 = -0.69375046  ; x2 = 0.46602608  dengan hasil 1.00598552
#
# Iterasi ke- 307 , suhu 107313.85 derajat
# Solusi Terbaik : x1 = -0.14575543  ; x2 = -0.35971984  dengan hasil 0.01561100
#
# Iterasi ke- 311 , suhu 105183.62 derajat
# Solusi Terbaik : x1 = -0.29282165  ; x2 = -0.30664389  dengan hasil -0.03873288
#
# Iterasi ke- 316 , suhu 102580.19 derajat
# Solusi Terbaik : x1 = 0.24742728  ; x2 = -0.41926207  dengan hasil 0.23583344
#
# Iterasi ke- 319 , suhu 101049.17 derajat
# Solusi Terbaik : x1 = -0.33910430  ; x2 = -0.85563051  dengan hasil 1.90206735
#
# Iterasi ke- 320 , suhu 100543.93 derajat
# Solusi Terbaik : x1 = 0.51641451  ; x2 = 0.27601975  dengan hasil 0.03054584
#
# Iterasi ke- 322 , suhu 99541.00 derajat
# Solusi Terbaik : x1 = -0.50866444  ; x2 = -0.21776399  dengan hasil 0.03900710
#
# Iterasi ke- 324 , suhu 98548.08 derajat
# Solusi Terbaik : x1 = -0.01281513  ; x2 = -0.70628471  dengan hasil 0.98632033
#
# Iterasi ke- 325 , suhu 98055.34 derajat
# Solusi Terbaik : x1 = -0.21307421  ; x2 = -0.00640064  dengan hasil 0.00296475
#
# Iterasi ke- 327 , suhu 97077.24 derajat
# Solusi Terbaik : x1 = -0.11387720  ; x2 = 0.23638217  dengan hasil 0.03977394
#
# Iterasi ke- 329 , suhu 96108.89 derajat
# Solusi Terbaik : x1 = -0.06439997  ; x2 = 0.61134869  dengan hasil 0.59834799
#
# Iterasi ke- 333 , suhu 94201.08 derajat
# Solusi Terbaik : x1 = 0.29001560  ; x2 = 0.95795736  dengan hasil 3.12920726
#
# Iterasi ke- 334 , suhu 93730.08 derajat
# Solusi Terbaik : x1 = -0.30057199  ; x2 = 0.49746449  dengan hasil 0.41347568
#
# Iterasi ke- 336 , suhu 92795.12 derajat
# Solusi Terbaik : x1 = 0.52564440  ; x2 = 0.45369227  dengan hasil 0.09521624
#
# Iterasi ke- 339 , suhu 91410.14 derajat
# Solusi Terbaik : x1 = -0.05057924  ; x2 = 0.09957627  dengan hasil 0.00544358
#
# Iterasi ke- 340 , suhu 90953.09 derajat
# Solusi Terbaik : x1 = 0.21213391  ; x2 = 0.05031503  dengan hasil -0.00639514
#
# Iterasi ke- 341 , suhu 90498.32 derajat
# Solusi Terbaik : x1 = 0.11176417  ; x2 = 0.20372844  dengan hasil -0.01554395
#
# Iterasi ke- 345 , suhu 88701.89 derajat
# Solusi Terbaik : x1 = -0.00192841  ; x2 = 0.46297068  dengan hasil 0.18466257
#
# Iterasi ke- 347 , suhu 87817.09 derajat
# Solusi Terbaik : x1 = 0.36496041  ; x2 = -0.80002089  dengan hasil 1.98599118
#
# Iterasi ke- 348 , suhu 87378.00 derajat
# Solusi Terbaik : x1 = -0.66336999  ; x2 = -0.28422407  dengan hasil 0.24518575
#
# Iterasi ke- 350 , suhu 86506.41 derajat
# Solusi Terbaik : x1 = -0.73556778  ; x2 = -0.23611144  dengan hasil 0.45408253
#
# Iterasi ke- 353 , suhu 85215.29 derajat
# Solusi Terbaik : x1 = -0.06999893  ; x2 = -0.16677892  dengan hasil -0.00852792
#
# Iterasi ke- 355 , suhu 84365.26 derajat
# Solusi Terbaik : x1 = -0.81226119  ; x2 = -0.38919005  dengan hasil 0.69481065
#
# Iterasi ke- 356 , suhu 83943.44 derajat
# Solusi Terbaik : x1 = -0.40846851  ; x2 = -0.36166304  dengan hasil -0.01988243
#
# Iterasi ke- 358 , suhu 83106.10 derajat
# Solusi Terbaik : x1 = -0.59832162  ; x2 = 0.05223600  dengan hasil 0.30041209
#
# Iterasi ke- 360 , suhu 82277.12 derajat
# Solusi Terbaik : x1 = -0.71827529  ; x2 = 0.68940023  dengan hasil 1.99652452
#
# Iterasi ke- 361 , suhu 81865.73 derajat
# Solusi Terbaik : x1 = 0.47935004  ; x2 = 0.63866773  dengan hasil 0.48299024
#
# Iterasi ke- 363 , suhu 81049.12 derajat
# Solusi Terbaik : x1 = -0.70781843  ; x2 = 0.27935042  dengan hasil 0.75022192
#
# Iterasi ke- 365 , suhu 80240.66 derajat
# Solusi Terbaik : x1 = 0.20716205  ; x2 = 0.60146943  dengan hasil 0.40463537
#
# Iterasi ke- 367 , suhu 79440.26 derajat
# Solusi Terbaik : x1 = -0.59811500  ; x2 = -0.74257146  dengan hasil 1.07709302
#
# Iterasi ke- 368 , suhu 79043.06 derajat
# Solusi Terbaik : x1 = 0.46846978  ; x2 = 0.34918872  dengan hasil -0.00188105
#
# Iterasi ke- 374 , suhu 76701.21 derajat
# Solusi Terbaik : x1 = -0.86556475  ; x2 = -0.47363229  dengan hasil 0.98263800
#
# Iterasi ke- 375 , suhu 76317.70 derajat
# Solusi Terbaik : x1 = -0.45348678  ; x2 = -0.11891775  dengan hasil 0.03569926
#
# Iterasi ke- 378 , suhu 75178.65 derajat
# Solusi Terbaik : x1 = 0.24639290  ; x2 = -0.55864309  dengan hasil 0.53693744
#
# Iterasi ke- 380 , suhu 74428.74 derajat
# Solusi Terbaik : x1 = -0.59540665  ; x2 = -0.65201067  dengan hasil 0.61996674
#
# Iterasi ke- 382 , suhu 73686.32 derajat
# Solusi Terbaik : x1 = 0.15806810  ; x2 = 0.52480646  dengan hasil 0.22241632
#
# Iterasi ke- 384 , suhu 72951.30 derajat
# Solusi Terbaik : x1 = -0.98711843  ; x2 = -0.36843482  dengan hasil 1.70986982
#
# Iterasi ke- 385 , suhu 72586.54 derajat
# Solusi Terbaik : x1 = -0.65423291  ; x2 = 0.18611583  dengan hasil 0.51145736
#
# Iterasi ke- 389 , suhu 71145.66 derajat
# Solusi Terbaik : x1 = 0.59301979  ; x2 = 0.81573261  dengan hasil 1.59900722
#
# Iterasi ke- 391 , suhu 70435.98 derajat
# Solusi Terbaik : x1 = -0.51031692  ; x2 = 0.11465485  dengan hasil 0.20163924
#
# Iterasi ke- 392 , suhu 70083.80 derajat
# Solusi Terbaik : x1 = 0.40225747  ; x2 = 0.51491957  dengan hasil 0.13284694
#
# Iterasi ke- 395 , suhu 69037.79 derajat
# Solusi Terbaik : x1 = 0.86143552  ; x2 = -0.10451841  dengan hasil 1.24694886
#
# Iterasi ke- 396 , suhu 68692.60 derajat
# Solusi Terbaik : x1 = -0.68138930  ; x2 = -0.01989099  dengan hasil 0.43913677
#
# Iterasi ke- 398 , suhu 68007.40 derajat
# Solusi Terbaik : x1 = -0.12206365  ; x2 = -0.51662359  dengan hasil 0.22270133
#
# Iterasi ke- 402 , suhu 66657.41 derajat
# Solusi Terbaik : x1 = -0.83290631  ; x2 = -0.54397583  dengan hasil 0.92807492
#
# Iterasi ke- 403 , suhu 66324.13 derajat
# Solusi Terbaik : x1 = -0.77130923  ; x2 = -0.17540375  dengan hasil 0.61193089
#
# Iterasi ke- 405 , suhu 65662.54 derajat
# Solusi Terbaik : x1 = -0.25712176  ; x2 = 0.43478162  dengan hasil 0.26469487
#
# Iterasi ke- 407 , suhu 65007.56 derajat
# Solusi Terbaik : x1 = -0.70546183  ; x2 = -0.12911369  dengan hasil 0.43020468
#
# Iterasi ke- 408 , suhu 64682.52 derajat
# Solusi Terbaik : x1 = 0.63286896  ; x2 = -0.04856181  dengan hasil 0.36763567
#
# Iterasi ke- 409 , suhu 64359.11 derajat
# Solusi Terbaik : x1 = 0.04865233  ; x2 = 0.07056617  dengan hasil -0.00332224
#
# Iterasi ke- 412 , suhu 63398.54 derajat
# Solusi Terbaik : x1 = 0.34103277  ; x2 = -0.13735237  dengan hasil 0.07668470
#
# Iterasi ke- 414 , suhu 62766.14 derajat
# Solusi Terbaik : x1 = -0.18765946  ; x2 = 0.12961236  dengan hasil 0.02805953
#
# Iterasi ke- 418 , suhu 61520.20 derajat
# Solusi Terbaik : x1 = -0.89539000  ; x2 = -0.57629141  dengan hasil 1.30445998
#
# Iterasi ke- 419 , suhu 61212.60 derajat
# Solusi Terbaik : x1 = -0.25470895  ; x2 = 0.71926936  dengan hasil 1.26842877
#
# Iterasi ke- 421 , suhu 60602.01 derajat
# Solusi Terbaik : x1 = 0.81714326  ; x2 = 0.45549923  dengan hasil 0.74585795
#
# Iterasi ke- 424 , suhu 59697.51 derajat
# Solusi Terbaik : x1 = -0.19975681  ; x2 = -0.55416291  dengan hasil 0.27113337
#
# Iterasi ke- 425 , suhu 59399.03 derajat
# Solusi Terbaik : x1 = 0.08340206  ; x2 = -0.12281232  dengan hasil 0.01125491
#
# Iterasi ke- 426 , suhu 59102.03 derajat
# Solusi Terbaik : x1 = 0.11224855  ; x2 = 0.05466063  dengan hasil -0.00576645
#
# Iterasi ke- 428 , suhu 58512.49 derajat
# Solusi Terbaik : x1 = 0.06735103  ; x2 = 0.35415490  dengan hasil 0.03914072
#
# Iterasi ke- 430 , suhu 57928.83 derajat
# Solusi Terbaik : x1 = 0.09120529  ; x2 = 0.03958729  dengan hasil -0.00345543
#
# Iterasi ke- 434 , suhu 56778.91 derajat
# Solusi Terbaik : x1 = 0.13883132  ; x2 = 0.93449843  dengan hasil 2.92646505
#
# Iterasi ke- 435 , suhu 56495.02 derajat
# Solusi Terbaik : x1 = 0.63503335  ; x2 = -0.63184637  dengan hasil 1.40171780
#
# Iterasi ke- 436 , suhu 56212.54 derajat
# Solusi Terbaik : x1 = 0.02949644  ; x2 = -0.47801818  dengan hasil 0.22296809
#
# Iterasi ke- 438 , suhu 55651.82 derajat
# Solusi Terbaik : x1 = 0.48705362  ; x2 = -0.52771846  dengan hasil 0.69155449
#
# Iterasi ke- 439 , suhu 55373.56 derajat
# Solusi Terbaik : x1 = 0.06120988  ; x2 = -0.40292867  dengan hasil 0.13015767
#
# Iterasi ke- 441 , suhu 54821.21 derajat
# Solusi Terbaik : x1 = 0.09329656  ; x2 = -0.68373329  dengan hasil 0.93877530
#
# Iterasi ke- 443 , suhu 54274.37 derajat
# Solusi Terbaik : x1 = -0.50688842  ; x2 = 0.22812130  dengan hasil 0.26533004
#
# Iterasi ke- 445 , suhu 53732.98 derajat
# Solusi Terbaik : x1 = 0.34648749  ; x2 = 0.17003826  dengan hasil -0.02527182
#
# Iterasi ke- 447 , suhu 53196.99 derajat
# Solusi Terbaik : x1 = 0.37593756  ; x2 = 0.42444803  dengan hasil 0.01373316
#
# Iterasi ke- 449 , suhu 52666.35 derajat
# Solusi Terbaik : x1 = 0.71557744  ; x2 = 0.20624389  dengan hasil 0.41057501
#
# Iterasi ke- 451 , suhu 52141.01 derajat
# Solusi Terbaik : x1 = -0.81103316  ; x2 = 0.01778313  dengan hasil 0.92302522
#
# Iterasi ke- 452 , suhu 51880.30 derajat
# Solusi Terbaik : x1 = -0.68129633  ; x2 = 0.15997677  dengan hasil 0.56415546
#
# Iterasi ke- 453 , suhu 51620.90 derajat
# Solusi Terbaik : x1 = -0.53971619  ; x2 = 0.29570336  dengan hasil 0.36911071
#
# Iterasi ke- 454 , suhu 51362.80 derajat
# Solusi Terbaik : x1 = -0.21270153  ; x2 = -0.31472640  dengan hasil -0.02325072
#
# Iterasi ke- 456 , suhu 50850.45 derajat
# Solusi Terbaik : x1 = -0.82417941  ; x2 = -0.32850955  dengan hasil 0.74743293
#
# Iterasi ke- 459 , suhu 50091.50 derajat
# Solusi Terbaik : x1 = 0.29479462  ; x2 = -0.66888976  dengan hasil 1.01955909
#
# Iterasi ke- 460 , suhu 49841.05 derajat
# Solusi Terbaik : x1 = -0.50958099  ; x2 = -0.08148460  dengan hasil 0.10026007
#
# Iterasi ke- 462 , suhu 49343.88 derajat
# Solusi Terbaik : x1 = -0.39219879  ; x2 = 0.18751644  dengan hasil 0.12823987
#
# Iterasi ke- 465 , suhu 48607.42 derajat
# Solusi Terbaik : x1 = -0.62971606  ; x2 = 0.07337291  dengan hasil 0.37654006
#
# Iterasi ke- 467 , suhu 48122.56 derajat
# Solusi Terbaik : x1 = 0.12445091  ; x2 = -0.75425267  dengan hasil 1.39061764
#
# Iterasi ke- 468 , suhu 47881.95 derajat
# Solusi Terbaik : x1 = 0.52595774  ; x2 = 0.61896821  dengan hasil 0.43581504
#
# Iterasi ke- 470 , suhu 47404.32 derajat
# Solusi Terbaik : x1 = -0.39789726  ; x2 = 0.30092903  dengan hasil 0.20561329
#
# Iterasi ke- 472 , suhu 46931.47 derajat
# Solusi Terbaik : x1 = -0.31206963  ; x2 = -0.53300220  dengan hasil 0.17903481
#
# Iterasi ke- 474 , suhu 46463.32 derajat
# Solusi Terbaik : x1 = -0.73812340  ; x2 = 0.22425519  dengan hasil 0.79945842
#
# Iterasi ke- 475 , suhu 46231.01 derajat
# Solusi Terbaik : x1 = -0.39857188  ; x2 = 0.55176095  dengan hasil 0.64855585
#
# Iterasi ke- 477 , suhu 45769.85 derajat
# Solusi Terbaik : x1 = 0.36167050  ; x2 = 0.83128439  dengan hasil 1.66621172
#
# Iterasi ke- 478 , suhu 45541.00 derajat
# Solusi Terbaik : x1 = 0.26891669  ; x2 = -0.70179923  dengan hasil 1.17586752
#
# Iterasi ke- 480 , suhu 45086.73 derajat
# Solusi Terbaik : x1 = -0.11316342  ; x2 = 0.52377953  dengan hasil 0.36099905
#
# Iterasi ke- 481 , suhu 44861.30 derajat
# Solusi Terbaik : x1 = 0.27439448  ; x2 = -0.14229161  dengan hasil 0.05259883
#
# Iterasi ke- 483 , suhu 44413.81 derajat
# Solusi Terbaik : x1 = 0.48873428  ; x2 = 0.34931951  dengan hasil 0.00983547
#
# Iterasi ke- 485 , suhu 43970.78 derajat
# Solusi Terbaik : x1 = 0.09248006  ; x2 = 0.89826613  dengan hasil 2.52317250
#
# Iterasi ke- 486 , suhu 43750.93 derajat
# Solusi Terbaik : x1 = -0.39209349  ; x2 = 0.08316687  dengan hasil 0.08243684
#
# Iterasi ke- 488 , suhu 43314.51 derajat
# Solusi Terbaik : x1 = -0.70869773  ; x2 = 0.29387499  dengan hasil 0.76909200
#
# Iterasi ke- 489 , suhu 43097.94 derajat
# Solusi Terbaik : x1 = -0.60661105  ; x2 = -0.30238996  dengan hasil 0.13539215
#
# Iterasi ke- 492 , suhu 42454.70 derajat
# Solusi Terbaik : x1 = 0.67592552  ; x2 = 0.21400032  dengan hasil 0.30240386
#
# Iterasi ke- 494 , suhu 42031.21 derajat
# Solusi Terbaik : x1 = -0.52478709  ; x2 = -0.74860275  dengan hasil 1.05146977
#
# Iterasi ke- 497 , suhu 41403.89 derajat
# Solusi Terbaik : x1 = -0.38362458  ; x2 = -0.10655917  dengan hasil 0.00512591
#
# Iterasi ke- 501 , suhu 40582.00 derajat
# Solusi Terbaik : x1 = -0.79804328  ; x2 = -0.42171833  dengan hasil 0.64845779
#
# Iterasi ke- 502 , suhu 40379.09 derajat
# Solusi Terbaik : x1 = 0.23294730  ; x2 = -0.21853144  dengan hasil 0.06625382
#
# Iterasi ke- 503 , suhu 40177.20 derajat
# Solusi Terbaik : x1 = -0.50576549  ; x2 = -0.27713290  dengan hasil 0.02134256
#
# Iterasi ke- 507 , suhu 39379.66 derajat
# Solusi Terbaik : x1 = 0.82288273  ; x2 = 0.32091176  dengan hasil 0.74362183
#
# Iterasi ke- 509 , suhu 38986.85 derajat
# Solusi Terbaik : x1 = -0.80493551  ; x2 = -0.21419019  dengan hasil 0.71804812
#
# Iterasi ke- 511 , suhu 38597.95 derajat
# Solusi Terbaik : x1 = 0.59075168  ; x2 = -0.56932981  dengan hasil 1.02457616
#
# Iterasi ke- 512 , suhu 38404.96 derajat
# Solusi Terbaik : x1 = 0.63745765  ; x2 = -0.29377447  dengan hasil 0.56482732
#
# Iterasi ke- 514 , suhu 38021.87 derajat
# Solusi Terbaik : x1 = 0.78377020  ; x2 = -0.53390891  dengan hasil 1.55258912
#
# Iterasi ke- 516 , suhu 37642.60 derajat
# Solusi Terbaik : x1 = 0.20753243  ; x2 = -0.02549398  dengan hasil 0.00918802
#
# Iterasi ke- 518 , suhu 37267.12 derajat
# Solusi Terbaik : x1 = 0.54977017  ; x2 = 0.50434842  dengan hasil 0.17989610
#
# Iterasi ke- 519 , suhu 37080.78 derajat
# Solusi Terbaik : x1 = 0.03982141  ; x2 = 0.03453585  dengan hasil -0.00136429
#
# Iterasi ke- 521 , suhu 36710.90 derajat
# Solusi Terbaik : x1 = 0.68250871  ; x2 = -0.46183610  dengan hasil 0.95991775
#
# Iterasi ke- 522 , suhu 36527.35 derajat
# Solusi Terbaik : x1 = -0.30375539  ; x2 = 0.15188114  dengan hasil 0.06615744
#
# Iterasi ke- 526 , suhu 35802.26 derajat
# Solusi Terbaik : x1 = -0.83001392  ; x2 = 0.44537632  dengan hasil 1.53278264
#
# Iterasi ke- 527 , suhu 35623.25 derajat
# Solusi Terbaik : x1 = 0.27524488  ; x2 = -0.74100246  dengan hasil 1.42959964
#
# Iterasi ke- 528 , suhu 35445.14 derajat
# Solusi Terbaik : x1 = 0.54206960  ; x2 = -0.45889034  dengan hasil 0.61178758
#
# Iterasi ke- 529 , suhu 35267.91 derajat
# Solusi Terbaik : x1 = -0.59087338  ; x2 = -0.51605650  dengan hasil 0.24299772
#
# Iterasi ke- 532 , suhu 34741.53 derajat
# Solusi Terbaik : x1 = -0.39800845  ; x2 = 0.10244307  dengan hasil 0.09391688
#
# Iterasi ke- 533 , suhu 34567.82
# derajat
# Solusi Terbaik : x1 = -0.30448073  ; x2 = -0.09855141  dengan hasil -0.01157754
#
# Iterasi ke- 538 , suhu 33712.23 derajat
# Solusi Terbaik : x1 = 0.54990157  ; x2 = -0.12758601  dengan hasil 0.26327197
#
# Iterasi ke- 540 , suhu 33375.95 derajat
# Solusi Terbaik : x1 = 0.78672348  ; x2 = -0.00629738  dengan hasil 0.80942038
#
# Iterasi ke- 541 , suhu 33209.07 derajat
# Solusi Terbaik : x1 = -0.79149312  ; x2 = -0.30648306  dengan hasil 0.61870906
#
# Iterasi ke- 542 , suhu 33043.02 derajat
# Solusi Terbaik : x1 = 0.38140400  ; x2 = 0.35653561  dengan hasil -0.02612640
#
# Iterasi ke- 544 , suhu 32713.42 derajat
# Solusi Terbaik : x1 = 0.02557920  ; x2 = -0.33628162  dengan hasil 0.05975867
#
# Iterasi ke- 546 , suhu 32387.10 derajat
# Solusi Terbaik : x1 = -0.34126080  ; x2 = 0.26225785  dengan hasil 0.13708590
#
# Iterasi ke- 547 , suhu 32225.17 derajat
# Solusi Terbaik : x1 = -0.10138118  ; x2 = 0.14599980  dengan hasil 0.01684251
#
# Iterasi ke- 550 , suhu 31744.20 derajat
# Solusi Terbaik : x1 = 0.81196514  ; x2 = 0.52602487  dengan hasil 0.80875411
#
# Iterasi ke- 554 , suhu 31114.06 derajat
# Solusi Terbaik : x1 = -0.15442384  ; x2 = -0.39390113  dengan hasil 0.03685399
#
# Iterasi ke- 557 , suhu 30649.68 derajat
# Solusi Terbaik : x1 = -0.11328378  ; x2 = -0.63434524  dengan hasil 0.57686084
#
# Iterasi ke- 558 , suhu 30496.43 derajat
# Solusi Terbaik : x1 = -0.67998443  ; x2 = -0.31281740  dengan hasil 0.27603485
#
# Iterasi ke- 561 , suhu 30041.27 derajat
# Solusi Terbaik : x1 = -0.97778523  ; x2 = -0.32029290  dengan hasil 1.65179552
#
# Iterasi ke- 562 , suhu 29891.06 derajat
# Solusi Terbaik : x1 = -0.57716591  ; x2 = 0.59525338  dengan hasil 1.09272553
#
# Iterasi ke- 563 , suhu 29741.61 derajat
# Solusi Terbaik : x1 = -0.55982395  ; x2 = 0.01850296  dengan hasil 0.21662371
#
# Iterasi ke- 566 , suhu 29297.71 derajat
# Solusi Terbaik : x1 = -0.43266537  ; x2 = 0.11189788  dengan hasil 0.12264277
#
# Iterasi ke- 569 , suhu 28860.44 derajat
# Solusi Terbaik : x1 = 0.55386613  ; x2 = -0.43674507  dengan hasil 0.58877880
#
# Iterasi ke- 570 , suhu 28716.14 derajat
# Solusi Terbaik : x1 = -0.13405018  ; x2 = 0.24750495  dengan hasil 0.04888917
#
# Iterasi ke- 571 , suhu 28572.56 derajat
# Solusi Terbaik : x1 = 0.10247052  ; x2 = 0.22507193  dengan hasil -0.01255804
#
# Iterasi ke- 576 , suhu 27865.35 derajat
# Solusi Terbaik : x1 = -0.11397999  ; x2 = 0.14692505  dengan hasil 0.01896696
#
# Iterasi ke- 577 , suhu 27726.02 derajat
# Solusi Terbaik : x1 = -0.27183213  ; x2 = -0.27670831  dengan hasil -0.04015721
#
# Iterasi ke- 579 , suhu 27449.46 derajat
# Solusi Terbaik : x1 = 0.46683807  ; x2 = 0.39510914  dengan hasil 0.01454476
#
# Iterasi ke- 582 , suhu 27039.77 derajat
# Solusi Terbaik : x1 = -0.39079957  ; x2 = -0.13274662  dengan hasil -0.00163752
#
# Iterasi ke- 585 , suhu 26636.20 derajat
# Solusi Terbaik : x1 = 0.88676965  ; x2 = 0.58766822  dengan hasil 1.28577560
#
# Iterasi ke- 587 , suhu 26370.50 derajat
# Solusi Terbaik : x1 = -0.15294973  ; x2 = -0.34664887  dengan hasil 0.00600093
#
# Iterasi ke- 590 , suhu 25976.92 derajat
# Solusi Terbaik : x1 = -0.77670232  ; x2 = -0.18848325  dengan hasil 0.62316077
#
# Iterasi ke- 591 , suhu 25847.03 derajat
# Solusi Terbaik : x1 = 0.37381440  ; x2 = 0.36983362  dengan hasil -0.02154043
#
# Iterasi ke- 595 , suhu 25333.96 derajat
# Solusi Terbaik : x1 = -0.59220603  ; x2 = -0.60811436  dengan hasil 0.46116699
#
# Iterasi ke- 597 , suhu 25081.25 derajat
# Solusi Terbaik : x1 = 0.81480561  ; x2 = 0.57308538  dengan hasil 0.91399980
#
# Iterasi ke- 600 , suhu 24706.91 derajat
# Solusi Terbaik : x1 = 0.59486823  ; x2 = 0.86655357  dengan hasil 2.06948874
#
# Iterasi ke- 601 , suhu 24583.38 derajat
# Solusi Terbaik : x1 = 0.66570958  ; x2 = 0.59886952  dengan hasil 0.54726981
#
# Iterasi ke- 603 , suhu 24338.16 derajat
# Solusi Terbaik : x1 = 0.99659824  ; x2 = 0.72496136  dengan hasil 2.54541531
#
# Iterasi ke- 604 , suhu 24216.47 derajat
# Solusi Terbaik : x1 = -0.42566651  ; x2 = -0.44568215  dengan hasil 0.03943473
#
# Iterasi ke- 606 , suhu 23974.91 derajat
# Solusi Terbaik : x1 = 0.15159375  ; x2 = -0.31378477  dengan hasil 0.08752929
#
# Iterasi ke- 611 , suhu 23381.50 derajat
# Solusi Terbaik : x1 = 0.40084732  ; x2 = 0.65926413  dengan hasil 0.55568036
#
# Iterasi ke- 613 , suhu 23148.27 derajat
# Solusi Terbaik : x1 = 0.61720136  ; x2 = 0.28723762  dengan hasil 0.15554763
#
# Iterasi ke- 614 , suhu 23032.53 derajat
# Solusi Terbaik : x1 = 0.48098209  ; x2 = 0.41767233  dengan hasil 0.03557724
#
# Iterasi ke- 616 , suhu 22802.78 derajat
# Solusi Terbaik : x1 = 0.23923072  ; x2 = 0.75903362  dengan hasil 1.15933894
#
# Iterasi ke- 619 , suhu 22462.44 derajat
# Solusi Terbaik : x1 = -0.20528320  ; x2 = 0.44101772  dengan hasil 0.24611002
#
# Iterasi ke- 620 , suhu 22350.13 derajat
# Solusi Terbaik : x1 = -0.11573024  ; x2 = 0.16456957  dengan hasil 0.02235965
#
# Iterasi ke- 622 , suhu 22127.19 derajat
# Solusi Terbaik : x1 = -0.02567567  ; x2 = -0.95468186  dengan hasil 3.29839848
#
# Iterasi ke- 623 , suhu 22016.55 derajat
# Solusi Terbaik : x1 = -0.80493014  ; x2 = 0.41348950  dengan hasil 1.33763159
#
# Iterasi ke- 624 , suhu 21906.47 derajat
# Solusi Terbaik : x1 = 0.60460005  ; x2 = -0.01132214  dengan hasil 0.28744824
#
# Iterasi ke- 625 , suhu 21796.94 derajat
# Solusi Terbaik : x1 = -0.26118732  ; x2 = 0.37974841  dengan hasil 0.19261613
#
# Iterasi ke- 627 , suhu 21579.51 derajat
# Solusi Terbaik : x1 = -0.29155607  ; x2 = -0.24051862  dengan hasil -0.04146945
#
# Iterasi ke- 630 , suhu 21257.44 derajat
# Solusi Terbaik : x1 = 0.48621263  ; x2 = 0.40469599  dengan hasil 0.03000057
#
# Iterasi ke-
#  632 , suhu 21045.39 derajat
# Solusi Terbaik : x1 = 0.98351327  ; x2 = -0.35923923  dengan hasil 2.39020391
#
# Iterasi ke- 633 , suhu 20940.17 derajat
# Solusi Terbaik : x1 = 0.71707211  ; x2 = -0.51153093  dengan hasil 1.20763885
#
# Iterasi ke- 636 , suhu 20627.63 derajat
# Solusi Terbaik : x1 = -0.53201021  ; x2 = -0.04925007  dengan hasil 0.14205089
#
# Iterasi ke- 637 , suhu 20524.49 derajat
# Solusi Terbaik : x1 = 0.00812652  ; x2 = -0.07344074  dengan hasil 0.00071319
#
# Iterasi ke- 640 , suhu 20218.16 derajat
# Solusi Terbaik : x1 = -0.82180643  ; x2 = -0.58195337  dengan hasil 0.96420644
#
# Iterasi ke- 641 , suhu 20117.07 derajat
# Solusi Terbaik : x1 = -0.53527501  ; x2 = -0.59816026  dengan hasil 0.37651333
#
# Iterasi ke- 642 , suhu 20016.49 derajat
# Solusi Terbaik : x1 = -0.28516897  ; x2 = -0.02752817  dengan hasil 0.00603977
#
# Iterasi ke- 644 , suhu 19816.82 derajat
# Solusi Terbaik : x1 = 0.06208975  ; x2 = 0.48536387  dengan hasil 0.19195454
#
# Iterasi ke- 646 , suhu 19619.15 derajat
# Solusi Terbaik : x1 = -0.78986394  ; x2 = -0.84283358  dengan hasil 2.27510010
#
# Iterasi ke- 647 , suhu 19521.05 derajat
# Solusi Terbaik : x1 = 0.36056339  ; x2 = 0.82543571  dengan hasil 1.61490811
#
# Iterasi ke- 649 , suhu 19326.33 derajat
# Solusi Terbaik : x1 = -0.80275698  ; x2 = -0.44162796  dengan hasil 0.67788469
#
# Iterasi ke- 650 , suhu 19229.70 derajat
# Solusi Terbaik : x1 = -0.59162032  ; x2 = -0.01220392  dengan hasil 0.25005147
#
# Iterasi ke- 653 , suhu 18942.69 derajat
# Solusi Terbaik : x1 = 0.01421567  ; x2 = -0.02968293  dengan hasil 0.00042515
#
# Iterasi ke- 656 , suhu 18659.97 derajat
# Solusi Terbaik : x1 = 0.24600577  ; x2 = -0.17298564  dengan hasil 0.05384663
#
# Iterasi ke- 658 , suhu 18473.84 derajat
# Solusi Terbaik : x1 = -0.21304207  ; x2 = -0.22399724  dengan hasil -0.03328678
#
# Iterasi ke- 660 , suhu 18289.56 derajat
# Solusi Terbaik : x1 = -0.00293199  ; x2 = -0.49707214  dengan hasil 0.24273828
#
# Iterasi ke- 662 , suhu 18107.12 derajat
# Solusi Terbaik : x1 = 0.42049824  ; x2 = 0.08440713  dengan hasil 0.03036922
#
# Iterasi ke- 667 , suhu 17658.95 derajat
# Solusi Terbaik : x1 = 0.94331509  ; x2 = 0.43546732  dengan hasil 1.40654884
#
# Iterasi ke- 669 , suhu 17482.80 derajat
# Solusi Terbaik : x1 = -0.14252584  ; x2 = 0.71869406  dengan hasil 1.17228196
#
# Iterasi ke- 671 , suhu 17308.41 derajat
# Solusi Terbaik : x1 = 0.55709910  ; x2 = 0.36371910  dengan hasil 0.07146543
#
# Iterasi ke- 672 , suhu 17221.87 derajat
# Solusi Terbaik : x1 = 0.38915017  ; x2 = 0.22784593  dengan hasil -0.02958989
#
# Iterasi ke- 674 , suhu 17050.08 derajat
# Solusi Terbaik : x1 = -0.12235248  ; x2 = -0.18943141  dengan hasil -0.01754964
#
# Iterasi ke- 675 , suhu 16964.83 derajat
# Solusi Terbaik : x1 = -0.37050847  ; x2 = -0.17678399  dengan hasil -0.02197420
#
# Iterasi ke- 677 , suhu 16795.61 derajat
# Solusi Terbaik : x1 = -0.80803511  ; x2 = 0.36506188  dengan hasil 1.26513362
#
# Iterasi ke- 678 , suhu 16711.63 derajat
# Solusi Terbaik : x1 = -0.45063515  ; x2 = -0.01032558  dengan hasil 0.08194731
#
# Iterasi ke- 680 , suhu 16544.93 derajat
# Solusi Terbaik : x1 = -0.09229786  ; x2 = 0.66792330  dengan hasil 0.85846315
#
# Iterasi ke- 681 , suhu 16462.20 derajat
# Solusi Terbaik : x1 = 0.19365138  ; x2 = -0.10801209  dengan hasil 0.02441609
#
# Iterasi ke- 683 , suhu 16297.99 derajat
# Solusi Terbaik : x1 = -0.59253708  ; x2 = 0.63303889  dengan hasil 1.29512792
#
# Iterasi ke- 686 , suhu 16054.74 derajat
# Solusi Terbaik : x1 = -0.24625515  ; x2 = 0.95744937  dengan hasil 3.62190994
#
# Iterasi ke- 687 , suhu 15974.47 derajat
# Solusi Terbaik : x1 = 0.26423878  ; x2 = 0.38424311  dengan hasil -0.00359327
#
# Iterasi ke- 690 , suhu 15736.05 derajat
# Solusi Terbaik : x1 = -0.72330141  ; x2 = -0.50283482  dengan hasil 0.47793871
#
# Iterasi ke- 691 , suhu 15657.37 derajat
# Solusi Terbaik : x1 = 0.60721623  ; x2 = 0.52082992  dengan hasil 0.27261483
#
# Iterasi ke- 694 , suhu 15423.68 derajat
# Solusi Terbaik : x1 = 0.31114174  ; x2 = 0.42312925  dengan hasil 0.01728141
#
# Iterasi ke- 696 , suhu 15269.83 derajat
# Solusi Terbaik : x1 = 0.44871573  ; x2 = 0.19114992  dengan hasil 0.00479210
#
# Iterasi ke- 699 , suhu 15041.93 derajat
# Solusi Terbaik : x1 = -0.13795257  ; x2 = 0.51963822  dengan hasil 0.36456012
#
# Iterasi ke- 701 , suhu 14891.88 derajat
# Solusi Terbaik : x1 = 0.53538164  ; x2 = 0.30474556  dengan hasil 0.04470152
#
# Iterasi ke- 705 , suhu 14596.27 derajat
# Solusi Terbaik : x1 = 0.80883831  ; x2 = -0.45313876  dengan hasil 1.44316627
#
# Iterasi ke- 708 , suhu 14378.42 derajat
# Solusi Terbaik : x1 = 0.07392088  ; x2 = 0.11117110  dengan hasil -0.00754390
#
# Iterasi ke- 709 , suhu 14306.53 derajat
# Solusi Terbaik : x1 = 0.10004360  ; x2 = 0.23774593  dengan hasil -0.01078448
#
# Iterasi ke- 711 , suhu 14163.82 derajat
# Solusi Terbaik : x1 = -0.95558999  ; x2 = -0.28002222  dengan hasil 1.50995781
#
# Iterasi ke- 712 , suhu 14093.00 derajat
# Solusi Terbaik : x1 = -0.62702155  ; x2 = -0.34136185  dengan hasil 0.16665380
#
# Iterasi ke- 713 , suhu 14022.54 derajat
# Solusi Terbaik : x1 = -0.51800584  ; x2 = -0.23619161  dengan hasil 0.04158038
#
# Iterasi ke- 716 , suhu 13813.25 derajat
# Solusi Terbaik : x1 = -0.34189614  ; x2 = -0.31386903  dengan hasil -0.03941828
#
# Iterasi ke- 720 , suhu 13539.05 derajat
# Solusi Terbaik : x1 = -0.41337830  ; x2 = -0.18466660  dengan hasil -0.01029810
#
# Iterasi ke- 723 , suhu 13336.98 derajat
# Solusi Terbaik : x1 = -0.49320063  ; x2 = 0.23285877  dengan hasil 0.25110008
#
# Iterasi ke- 726 , suhu 13137.92 derajat
# Solusi Terbaik : x1 = 0.25824645  ; x2 = -0.24304798  dengan hasil 0.08614222
#
# Iterasi ke- 728 , suhu 13006.87 derajat
# Solusi Terbaik : x1 = 0.22679433  ; x2 = 0.15411662  dengan hasil -0.02713067
#
# Iterasi ke- 729 , suhu 12941.84 derajat
# Solusi Terbaik : x1 = 0.37014952  ; x2 = 0.33005744  dengan hasil -0.03473770
#
# Iterasi ke- 731 , suhu 12812.74 derajat
# Solusi Terbaik : x1 = -0.22367900  ; x2 = -0.52739181  dengan hasil 0.19803269
#
# Iterasi ke- 733 , suhu 12684.93 derajat
# Solusi Terbaik : x1 = 0.05885196  ; x2 = -0.11434929  dengan hasil 0.00743897
#
# Iterasi ke- 736 , suhu 12495.61 derajat
# Solusi Terbaik : x1 = -0.64463887  ; x2 = -0.49049771  dengan hasil 0.28600232
#
# Iterasi ke- 737 , suhu 12433.13 derajat
# Solusi Terbaik : x1 = -0.19415840  ; x2 = -0.27688671  dengan hasil -0.02719086
#
# Iterasi ke- 739 , suhu 12309.11 derajat
# Solusi Terbaik : x1 = -0.65150132  ; x2 = 0.46955251  dengan hasil 0.88557523
#
# Iterasi ke- 741 , suhu 12186.33 derajat
# Solusi Terbaik : x1 = 0.52286091  ; x2 = 0.40221437  dengan hasil 0.05372016
#
# Iterasi ke- 743 , suhu 12064.77 derajat
# Solusi Terbaik : x1 = -0.31071665  ; x2 = 0.58929965  dengan hasil 0.68895733
#
# Iterasi ke- 746 , suhu 11884.70 derajat
# Solusi Terbaik : x1 = 0.50932855  ; x2 = 0.27615444  dengan hasil 0.02443521
#
# Iterasi ke- 749 , suhu 11707.32 derajat
# Solusi Terbaik : x1 = -0.31079120  ; x2 = 0.62259284  dengan hasil 0.81892949
#
# Iterasi ke- 751 , suhu 11590.54 derajat
# Solusi Terbaik : x1 = 0.26407057  ; x2 = 0.67970001  dengan hasil 0.68943099
#
# Iterasi ke- 754 , suhu 11417.55 derajat
# Solusi Terbaik : x1 = -0.74409436  ; x2 = -0.23707338  dengan hasil 0.48058441
#
# Iterasi ke- 755 , suhu 11360.46 derajat
# Solusi Terbaik : x1 = 0.25552835  ; x2 = 0.48729897  dengan hasil 0.11121127
#
# Iterasi ke- 756 , suhu 11303.66 derajat
# Solusi Terbaik : x1 = -0.25472985  ; x2 = 0.25818570  dengan hasil 0.09247962
#
# Iterasi ke- 759 , suhu 11134.95 derajat
# Solusi Terbaik : x1 = 0.09643571  ; x2 = -0.81184844  dengan hasil 1.81745953
#
# Iterasi ke- 761 , suhu 11023.88 derajat
# Solusi Terbaik : x1 = 0.56857472  ; x2 = 0.63133906  dengan hasil 0.51311652
#
# Iterasi ke- 762 , suhu 10968.76 derajat
# Solusi Terbaik : x1 = -0.01632977  ; x2 = 0.42148955  dengan hasil 0.13312876
#
# Iterasi ke- 765 , suhu 10805.05 derajat
# Solusi Terbaik : x1 = 0.19054403  ; x2 = -0.29719018  dengan hasil 0.09069355
#
# Iterasi ke- 767 , suhu 10697.27 derajat
# Solusi Terbaik : x1 = -0.85313152  ; x2 = -0.49633648  dengan hasil 0.94649349
#
# Iterasi ke- 768 , suhu 10643.78 derajat
# Solusi Terbaik : x1 = 0.60909218  ; x2 = -0.50269962  dengan hasil 0.85856648
#
# Iterasi ke- 769 , suhu 10590.56 derajat
# Solusi Terbaik : x1 = -0.12301945  ; x2 = 0.29404929  dengan hasil 0.06659724
#
# Iterasi ke- 771 , suhu 10484.92 derajat
# Solusi Terbaik : x1 = -0.85408439  ; x2 = 0.00313314  dengan hasil 1.12011140
#
# Iterasi ke- 774 , suhu 10328.43 derajat
# Solusi Terbaik : x1 = 0.78650173  ; x2 = -0.03304924  dengan hasil 0.82955776
#
# Iterasi ke- 775 , suhu 10276.79 derajat
# Solusi Terbaik : x1 = 0.36734462  ; x2 = 0.42667457  dengan hasil 0.01556437
#
# Iterasi ke- 777 , suhu 10174.28 derajat
# Solusi Terbaik : x1 = 0.12664510  ; x2 = 0.34761326  dengan hasil 0.01499914
#
# Iterasi ke- 779 , suhu 10072.79 derajat
# Solusi Terbaik : x1 = -0.08967040  ; x2 = 0.36671204  dengan hasil 0.10540449
#
# Iterasi ke- 780 , suhu 10022.43 derajat
# Solusi Terbaik : x1 = -0.34067656  ; x2 = -0.05444637  dengan hasil 0.00977398
#
# Iterasi ke- 783 , suhu 9872.84 derajat
# Solusi Terbaik : x1 = -0.78718248  ; x2 = 0.29931560  dengan hasil 1.07572436
#
# Iterasi ke- 785 , suhu 9774.36 derajat
# Solusi Terbaik : x1 = 0.85359820  ; x2 = 0.20642726  dengan hasil 0.94639148
#
# Iterasi ke- 786 , suhu 9725.49 derajat
# Solusi Terbaik : x1 = -0.37676417  ; x2 = -0.71588349  dengan hasil 0.83560427
#
# Iterasi ke- 789 , suhu 9580.34 derajat
# Solusi Terbaik : x1 = -0.95264319  ; x2 = -0.42457516  dengan hasil 1.46492081
#
# Iterasi ke- 790 , suhu 9532.43 derajat
# Solusi Terbaik : x1 = -0.43898031  ; x2 = -0.78032833  dengan hasil 1.24234744
#
# Iterasi ke- 791 , suhu 9484.77 derajat
# Solusi Terbaik : x1 = 0.20650576  ; x2 = -0.21827338  dengan hasil 0.05800549
#
# Iterasi ke- 794 , suhu 9343.21 derajat
# Solusi Terbaik : x1 = -0.59311392  ; x2 = -0.78114654  dengan hasil 1.32955750
#
# Iterasi ke- 795 , suhu 9296.49 derajat
# Solusi Terbaik : x1 = 0.50737214  ; x2 = 0.39352953  dengan hasil 0.03748898
#
# Iterasi ke- 797 , suhu 9203.76 derajat
# Solusi Terbaik : x1 = -0.55556321  ; x2 = 0.30615817  dengan hasil 0.40619424
#
# Iterasi ke- 799 , suhu 9111.95 derajat
# Solusi Terbaik : x1 = 0.56208990  ; x2 = -0.28343773  dengan hasil 0.39543798
#
# Iterasi ke- 800 , suhu 9066.39 derajat
# Solusi Terbaik : x1 = -0.18215134  ; x2 = -0.09654379  dengan hasil -0.01492533
#
# Iterasi ke- 802 , suhu 8975.96 derajat
# Solusi Terbaik : x1 = -0.64322389  ; x2 = 0.34728887  dengan hasil 0.64305172
#
# Iterasi ke- 803 , suhu 8931.08 derajat
# ...
#
# Iterasi ke- 2585 , suhu 1.18 derajat
# Solusi Terbaik : x1 = -0.08796987  ; x2 = 0.20456914  dengan hasil 0.02513140
#
# Iterasi ke- 2589 , suhu 1.16 derajat
# Solusi Terbaik : x1 = -0.52952871  ; x2 = 0.41747274  dengan hasil 0.51051329
#
# Iterasi ke- 2590 , suhu 1.15 derajat
# Solusi Terbaik : x1 = -0.09586006  ; x2 = -0.16444290  dengan hasil -0.01265898
#
# Iterasi ke- 2591 , suhu 1.14 derajat
# Solusi Terbaik : x1 = -0.32646895  ; x2 = -0.20562012  dengan hasil -0.03605940
#
# Iterasi ke- 2599 , suhu 1.10 derajat
# Solusi Terbaik : x1 = -0.90908743  ; x2 = -0.49411502  dengan hasil 1.23996988
#
# Iterasi ke- 2600 , suhu 1.09 derajat
# Solusi Terbaik : x1 = 0.85999665  ; x2 = 0.59494555  dengan hasil 1.16908678
#
# Iterasi ke- 2601 , suhu 1.09 derajat
# Solusi Terbaik : x1 = -0.09869575  ; x2 = 0.45895809  dengan hasil 0.22312164
#
# Iterasi ke- 2603 , suhu 1.08 derajat
# Solusi Terbaik : x1 = 0.40340883  ; x2 = -0.16379430  dengan hasil 0.12461035
#
# Iterasi ke- 2605 , suhu 1.07 derajat
# Solusi Terbaik : x1 = 0.00580659  ; x2 = 0.22108815  dengan hasil 0.00827327
#
# Iterasi ke- 2608 , suhu 1.05 derajat
# Solusi Terbaik : x1 = 0.33167639  ; x2 = 0.03553197  dengan hasil 0.01363558
#
# Iterasi ke- 2609 , suhu 1.05 derajat
# Solusi Terbaik : x1 = 0.18415216  ; x2 = 0.36877765  dengan hasil 0.00869361
#
# Iterasi ke- 2618 , suhu 1.00 derajat
# Solusi Terbaik : x1 = -0.56237261  ; x2 = -0.31779507  dengan hasil 0.07320168
#
# Iterasi ke- 2620 , suhu 0.99 derajat
# Solusi Terbaik : x1 = -0.85145576  ; x2 = -0.25385180  dengan hasil 0.90521258
#
# Iterasi ke- 2621 , suhu 0.98 derajat
# Solusi Terbaik : x1 = -0.18330646  ; x2 = 0.45912084  dengan hasil 0.26476146
#
# Iterasi ke- 2624 , suhu 0.97 derajat
# Solusi Terbaik : x1 = -0.30166799  ; x2 = -0.13061001  dengan hasil -0.02083653
#
# Iterasi ke- 2631 , suhu 0.94 derajat
# Solusi Terbaik : x1 = 0.66720222  ; x2 = -0.32681656  dengan hasil 0.68152761
#
# Iterasi ke- 2632 , suhu 0.93 derajat
# Solusi Terbaik : x1 = -0.16847719  ; x2 = 0.42596745  dengan hasil 0.20546314
#
# Iterasi ke- 2635 , suhu 0.92 derajat
# Solusi Terbaik : x1 = 0.90664358  ; x2 = 0.30678694  dengan hasil 1.17865904
#
# Iterasi ke- 2636 , suhu 0.91 derajat
# Solusi Terbaik : x1 = 0.13715008  ; x2 = 0.46410126  dengan hasil 0.12295376
#
# Iterasi ke- 2637 , suhu 0.91 derajat
# Solusi Terbaik : x1 = -0.36536541  ; x2 = -0.07614125  dengan hasil 0.00973874
#
# Iterasi ke- 2642 , suhu 0.89 derajat
# Solusi Terbaik : x1 = -0.74854706  ; x2 = 0.79415488  dengan hasil 2.91911180
#
# Iterasi ke- 2643 , suhu 0.88 derajat
# Solusi Terbaik : x1 = 0.22587852  ; x2 = -0.64799840  dengan hasil 0.86010468
#
# Iterasi ke- 2645 , suhu 0.87 derajat
# Solusi Terbaik : x1 = -0.20767373  ; x2 = -0.43483217  dengan hasil 0.05712035
#
# Iterasi ke- 2648 , suhu 0.86 derajat
# Solusi Terbaik : x1 = -0.23551505  ; x2 = 0.12383737  dengan hasil 0.03657156
#
# Iterasi ke- 2658 , suhu 0.82 derajat
# Solusi Terbaik : x1 = -0.66667207  ; x2 = 0.41583265  dengan hasil 0.81608288
#
# Iterasi ke- 2661 , suhu 0.81 derajat
# Solusi Terbaik : x1 = -0.44309851  ; x2 = 0.13065854  dengan hasil 0.14003012
#
# Iterasi ke- 2664 , suhu 0.79 derajat
# Solusi Terbaik : x1 = -0.31785680  ; x2 = -0.21043411  dengan hasil -0.03754203
#
# Iterasi ke- 2667 , suhu 0.78 derajat
# Solusi Terbaik : x1 = -0.51424136  ; x2 = -0.46257054  dengan hasil 0.09615259
#
# Iterasi ke- 2672 , suhu 0.76 derajat
# Solusi Terbaik : x1 = 0.69031292  ; x2 = 0.21527689  dengan hasil 0.33719747
#
# Iterasi ke- 2677 , suhu 0.74 derajat
# Solusi Terbaik : x1 = 0.64326413  ; x2 = 0.53893896  dengan hasil 0.36197747
#
# Iterasi ke- 2678 , suhu 0.74 derajat
# Solusi Terbaik : x1 = 0.21708877  ; x2 = 0.34879614  dengan hasil -0.01161970
#
# Iterasi ke- 2680 , suhu 0.73 derajat
# Solusi Terbaik : x1 = 0.58117373  ; x2 = -0.66802563  dengan hasil 1.44682199
#
# Iterasi ke- 2681 , suhu 0.73 derajat
# Solusi Terbaik : x1 = -0.18643329  ; x2 = 0.04974748  dengan hasil 0.01183611
#
# Iterasi ke- 2683 , suhu 0.72 derajat
# Solusi Terbaik : x1 = 0.53582247  ; x2 = 0.15436232  dengan hasil 0.09271694
#
# Iterasi ke- 2685 , suhu 0.71 derajat
# Solusi Terbaik : x1 = -0.23446201  ; x2 = -0.36204024  dengan hasil -0.00950307
#
# Iterasi ke- 2692 , suhu 0.69 derajat
# Solusi Terbaik : x1 = -0.06099800  ; x2 = -0.00267262  dengan hasil -0.00013395
#
# Iterasi ke- 2702 , suhu 0.66 derajat
# Solusi Terbaik : x1 = -0.17858311  ; x2 = -0.52621834  dengan hasil 0.21568448
#
# Iterasi ke- 2704 , suhu 0.65 derajat
# Solusi Terbaik : x1 = -0.43715499  ; x2 = 0.35233873  dengan hasil 0.29334783
#
# Iterasi ke- 2707 , suhu 0.64 derajat
# Solusi Terbaik : x1 = -0.62664981  ; x2 = -0.08680076  dengan hasil 0.26967221
#
# Iterasi ke- 2709 , suhu 0.63 derajat
# Solusi Terbaik : x1 = -0.54626401  ; x2 = -0.38194928  dengan hasil 0.06559667
#
# Iterasi ke- 2714 , suhu 0.62 derajat
# Solusi Terbaik : x1 = -0.28776122  ; x2 = -0.43397011  dengan hasil 0.03237161
#
# Iterasi ke- 2718 , suhu 0.61 derajat
# Solusi Terbaik : x1 = 0.49707937  ; x2 = -0.17780833  dengan hasil 0.22067552
#
# Iterasi ke- 2720 , suhu 0.60 derajat
# Solusi Terbaik : x1 = 0.16470936  ; x2 = 0.46412026  dengan hasil 0.11112200
#
# Iterasi ke-
# 2721 , suhu 0.60 derajat
# Solusi Terbaik : x1 = -0.11443237  ; x2 = -0.40419427  dengan hasil 0.06098665
#
# Iterasi ke- 2731 , suhu 0.57 derajat
# Solusi Terbaik : x1 = 0.26905598  ; x2 = 0.05535467  dengan hasil -0.00385073
#
# Iterasi ke- 2740 , suhu 0.54 derajat
# Solusi Terbaik : x1 = -0.07063557  ; x2 = 0.02140153  dengan hasil 0.00156483
#
# Iterasi ke- 2744 , suhu 0.53 derajat
# Solusi Terbaik : x1 = 0.31185300  ; x2 = 0.42704111  dengan hasil 0.02079254
#
# Iterasi ke- 2749 , suhu 0.52 derajat
# Solusi Terbaik : x1 = -0.48305220  ; x2 = -0.08814336  dengan hasil 0.07200761
#
# Iterasi ke- 2754 , suhu 0.51 derajat
# Solusi Terbaik : x1 = -0.53606975  ; x2 = -0.49880913  dengan hasil 0.15958245
#
# Iterasi ke- 2755 , suhu 0.50 derajat
# Solusi Terbaik : x1 = 0.10410418  ; x2 = 0.35509954  dengan hasil 0.02693724
#
# Iterasi ke- 2759 , suhu 0.49 derajat
# Solusi Terbaik : x1 = -0.39842234  ; x2 = -0.08977008  dengan hasil 0.01741365
#
# Iterasi ke- 2764 , suhu 0.48 derajat
# Solusi Terbaik : x1 = -0.28941678  ; x2 = -0.11742192  dengan hasil -0.01848436
#
# Iterasi ke- 2769 , suhu 0.47 derajat
# Solusi Terbaik : x1 = -0.27428652  ; x2 = 0.64738756  dengan hasil 0.89647565
#
# Iterasi ke- 2770 , suhu 0.47 derajat
# Solusi Terbaik : x1 = -0.30701525  ; x2 = 0.15435668  dengan hasil 0.06833614
#
# Iterasi ke- 2772 , suhu 0.46 derajat
# Solusi Terbaik : x1 = 0.58046202  ; x2 = 0.44984099  dengan hasil 0.14568122
#
# Iterasi ke- 2773 , suhu 0.46 derajat
# Solusi Terbaik : x1 = -0.18299858  ; x2 = -0.39555822  dengan hasil 0.02816862
#
# Iterasi ke- 2779 , suhu 0.45 derajat
# Solusi Terbaik : x1 = -0.38876324  ; x2 = -0.30558166  dengan hasil -0.03551127
#
# Iterasi ke- 2782 , suhu 0.44 derajat
# Solusi Terbaik : x1 = -0.28333514  ; x2 = -0.40995607  dengan hasil 0.01111672
#
# Iterasi ke- 2787 , suhu 0.43 derajat
# Solusi Terbaik : x1 = -0.04070325  ; x2 = -0.39047231  dengan hasil 0.07711183
#
# Iterasi ke- 2788 , suhu 0.43 derajat
# Solusi Terbaik : x1 = 0.38437848  ; x2 = 0.15100392  dengan hasil -0.01009614
#
# Iterasi ke- 2791 , suhu 0.42 derajat
# Solusi Terbaik : x1 = -0.28084803  ; x2 = -0.19111263  dengan hasil -0.03523765
#
# Iterasi ke- 2793 , suhu 0.42 derajat
# Solusi Terbaik : x1 = 0.57335549  ; x2 = 0.44728649  dengan hasil 0.13497836
#
# Iterasi ke- 2797 , suhu 0.41 derajat
# Solusi Terbaik : x1 = 0.48603870  ; x2 = 0.36271540  dengan hasil 0.01149724
#
# Iterasi ke- 2799 , suhu 0.40 derajat
# Solusi Terbaik : x1 = -0.29080796  ; x2 = -0.12234754  dengan hasil -0.01965793
#
# Iterasi ke- 2804 , suhu 0.39 derajat
# Solusi Terbaik : x1 = -0.12969625  ; x2 = -0.49727261  dengan hasil 0.18103236
#
# Iterasi ke- 2806 , suhu 0.39 derajat
# Solusi Terbaik : x1 = -0.23710625  ; x2 = -0.23979186  dengan hasil -0.03693183
#
# Iterasi ke- 2813 , suhu 0.38 derajat
# Solusi Terbaik : x1 = -0.15793860  ; x2 = -0.16400242  dengan hasil -0.02169586
#
# Iterasi ke- 2831 , suhu 0.34 derajat
# Solusi Terbaik : x1 = -0.21363881  ; x2 = -0.38723491  dengan hasil 0.01192936
#
# Iterasi ke- 2832 , suhu 0.34 derajat
# Solusi Terbaik : x1 = 0.23349210  ; x2 = 0.37844150  dengan hasil 0.00029697
#
# Iterasi ke- 2844 , suhu 0.32 derajat
# Solusi Terbaik : x1 = 0.70452188  ; x2 = -0.02880946  dengan hasil 0.53766498
#
# Iterasi ke- 2845 , suhu 0.32 derajat
# Solusi Terbaik : x1 = 0.44734734  ; x2 = -0.36486664  dengan hasil 0.31939679
#
# Iterasi ke- 2846 , suhu 0.32 derajat
# Solusi Terbaik : x1 = -0.16357094  ; x2 = 0.10262620  dengan hasil 0.01873465
#
# Iterasi ke- 2850 , suhu 0.31 derajat
# Solusi Terbaik : x1 = -0.28501759  ; x2 = 0.00909137  dengan hasil 0.01644940
#
# Iterasi ke- 2857 , suhu 0.30 derajat
# Solusi Terbaik : x1 = -0.52206703  ; x2 = -0.25437304  dengan hasil 0.04032780
#
# Iterasi ke- 2861 , suhu 0.30 derajat
# Solusi Terbaik : x1 = 0.41835073  ; x2 = 0.29061613  dengan hasil -0.02830565
#
# Iterasi ke- 2865 , suhu 0.29 derajat
# Solusi Terbaik : x1 = -0.21746732  ; x2 = 0.22328220  dengan hasil 0.06323455
#
# Iterasi ke- 2877 , suhu 0.27 derajat
# Solusi Terbaik : x1 = -0.45660420  ; x2 = -0.44575355  dengan hasil 0.04841222
#
# Iterasi ke- 2880 , suhu 0.27 derajat
# Solusi Terbaik : x1 = -0.28086776  ; x2 = 0.17415842  dengan hasil 0.06568813
#
# Iterasi ke- 2882 , suhu 0.27 derajat
# Solusi Terbaik : x1 = -0.39154921  ; x2 = 0.51482837  dengan hasil 0.53553180
#
# Iterasi ke- 2883 , suhu 0.26 derajat
# Solusi Terbaik : x1 = 0.55029008  ; x2 = 0.30331202  dengan hasil 0.06036824
#
# Iterasi ke- 2886 , suhu 0.26 derajat
# Solusi Terbaik : x1 = -0.22957112  ; x2 = 0.00066944  dengan hasil 0.00598664
#
# Iterasi ke- 2889 , suhu 0.26 derajat
# Solusi Terbaik : x1 = -0.20870484  ; x2 = -0.24969957  dengan hasil -0.03252276
#
# Iterasi ke- 2908 , suhu 0.23 derajat
# Solusi Terbaik : x1 = 0.30149341  ; x2 = 0.41901065  dengan hasil 0.01525546
#
# Iterasi ke- 2912 , suhu 0.23 derajat
# Solusi Terbaik : x1 = -0.18534372  ; x2 = 0.14986640  dengan hasil 0.03227854
#
# Iterasi ke- 2917 , suhu 0.22 derajat
# Solusi Terbaik : x1 = -0.13697293  ; x2 = 0.15677976  dengan hasil 0.02463424
#
# Iterasi ke- 2927 , suhu 0.21 derajat
# Solusi Terbaik : x1 = -0.33841829  ; x2 = -0.20727062  dengan hasil -0.03514660
#
# Iterasi ke- 2956 , suhu 0.18 derajat
# Solusi Terbaik : x1 = -0.02722586  ; x2 = 0.19217777  dengan hasil 0.01068967
#
# Iterasi ke- 2957 , suhu 0.18 derajat
# Solusi Terbaik : x1 = -0.21938883  ; x2 = -0.28117901  dengan hasil -0.03171934
#
# Iterasi ke- 2964 , suhu 0.18 derajat
# Solusi Terbaik : x1 = -0.27411200  ; x2 = -0.41025977  dengan hasil 0.01342539
#
# Iterasi ke- 2975 , suhu 0.17 derajat
# Solusi Terbaik : x1 = 0.05373349  ; x2 = -0.06694278  dengan hasil 0.00369492
#
# Iterasi ke- 2988 , suhu 0.16 derajat
# Solusi Terbaik : x1 = -0.33839876  ; x2 = -0.52164564  dengan hasil 0.15002481
#
# Iterasi ke- 2991 , suhu 0.15 derajat
# Solusi Terbaik : x1 = 0.44274626  ; x2 = 0.22441001  dengan hasil -0.00835295
#
# Iterasi ke- 3000 , suhu 0.15 derajat
# Solusi Terbaik : x1 = -0.41602604  ; x2 = -0.26653203  dengan hasil -0.02749943
#
# Iterasi ke- 3010 , suhu 0.14 derajat
# Solusi Terbaik : x1 = -0.33366305  ; x2 = -0.17451624  dengan hasil -0.02845629
#
# Iterasi ke- 3019 , suhu 0.13 derajat
# Solusi Terbaik : x1 = 0.37075987  ; x2 = -0.07140387  dengan hasil 0.06626055
#
# Iterasi ke- 3025 , suhu 0.13 derajat
# Solusi Terbaik : x1 = 0.10982332  ; x2 = 0.08197789  dengan hasil -0.00851676
#
# Iterasi ke- 3029 , suhu 0.13 derajat
# Solusi Terbaik : x1 = 0.29918016  ; x2 = 0.19500786  dengan hasil -0.03568998
#
# Iterasi ke- 3051 , suhu 0.11 derajat
# Solusi Terbaik : x1 = -0.17129276  ; x2 = 0.12310994  dengan hasil 0.02381682
#
# Iterasi ke- 3060 , suhu 0.11 derajat
# Solusi Terbaik : x1 = 0.28909190  ; x2 = 0.02120658  dengan hasil 0.00853790
#
# Iterasi ke- 3072 , suhu 0.10 derajat
# Solusi Terbaik : x1 = -0.19437880  ; x2 = -0.05521647  dengan hasil -0.00769773
#
# Iterasi ke- 3074 , suhu 0.10 derajat
# Solusi Terbaik : x1 = -0.33479536  ; x2 = -0.35878622  dengan hasil -0.02683392
#
# Iterasi ke- 3089 , suhu 0.09 derajat
# Solusi Terbaik : x1 = -0.65617001  ; x2 = -0.00592419  dengan hasil 0.38541310
#
# Iterasi ke- 3090 , suhu 0.09 derajat
# Solusi Terbaik : x1 = -0.50099162  ; x2 = 0.21621102  dengan hasil 0.24953824
#
# Iterasi ke- 3091 , suhu 0.09 derajat
# Solusi Terbaik : x1 = 0.12922111  ; x2 = -0.42030261  dengan hasil 0.17989815
#
# Iterasi ke- 3095 , suhu 0.09 derajat
# Solusi Terbaik : x1 = -0.01755551  ; x2 = -0.27713539  dengan hasil 0.01873099
#
# Iterasi ke- 3111 , suhu 0.08 derajat
# Solusi Terbaik : x1 = 0.45512736  ; x2 = 0.08493044  dengan hasil 0.05166299
#
# Iterasi ke- 3117 , suhu 0.08 derajat
# Solusi Terbaik : x1 = 0.18074343  ; x2 = 0.37582740  dengan hasil 0.01433205
#
# Iterasi ke- 3137 , suhu 0.07 derajat
# Solusi Terbaik : x1 = -0.10661470  ; x2 = 0.14398052  dengan hasil 0.01734239
#
# Iterasi ke- 3140 , suhu 0.07 derajat
# Solusi Terbaik : x1 = -0.17955843  ; x2 = -0.19931122  dengan hasil -0.02727582
#
# Iterasi ke- 3152 , suhu 0.07 derajat
# Solusi Terbaik : x1 = -0.38280895  ; x2 = -0.33259656  dengan hasil -0.03267864
#
# Iterasi ke- 3184 , suhu 0.06 derajat
# Solusi Terbaik : x1 = 0.18755174  ; x2 = -0.10046985  dengan hasil 0.02185045
#
# Iterasi ke- 3189 , suhu 0.06 derajat
# Solusi Terbaik : x1 = 0.39297566  ; x2 = 0.15242833  dengan hasil -0.00763146
#
# Iterasi ke- 3196 , suhu 0.06 derajat
# Solusi Terbaik : x1 = -0.30391134  ; x2 = -0.25783642  dengan hasil -0.04263059
#
# Iterasi ke- 3207 , suhu 0.05 derajat
# Solusi Terbaik : x1 = 0.36874694  ; x2 = 0.20763817  dengan hasil -0.03021963
#
# Iterasi ke- 3235 , suhu 0.05 derajat
# Solusi Terbaik : x1 = -0.26861566  ; x2 = -0.10281254  dengan hasil -0.01623430
#
# Iterasi ke- 3256 , suhu 0.04 derajat
# Solusi Terbaik : x1 = 0.44786320  ; x2 = 0.47356184  dengan hasil 0.07693247
#
# Iterasi ke- 3257 , suhu 0.04 derajat
# Solusi Terbaik : x1 = 0.18728509  ; x2 = 0.29148548  dengan hasil -0.02304746
#
# Iterasi ke- 3284 , suhu 0.04 derajat
# Solusi Terbaik : x1 = -0.18011968  ; x2 = -0.21492390  dengan hasil -0.02794368
#
# Iterasi ke- 3313 , suhu 0.03 derajat
# Solusi Terbaik : x1 = -0.40028865  ; x2 = -0.12193588  dengan hasil 0.00600188
#
# Iterasi ke- 3323 , suhu 0.03 derajat
# Solusi Terbaik : x1 = -0.11262480  ; x2 = -0.16862309  dengan hasil -0.01541594
#
# Iterasi ke- 3349 , suhu 0.03 derajat
# Solusi Terbaik : x1 = 0.19108058  ; x2 = 0.31464863  dengan hasil -0.01799744
#
# Iterasi ke- 3370 , suhu 0.02 derajat
# Solusi Terbaik : x1 = -0.29269692  ; x2 = -0.25703590  dengan hasil -0.04223617
#
# Iterasi ke- 3393 , suhu 0.02 derajat
# Solusi Terbaik : x1 = -0.40671669  ; x2 = -0.30314046  dengan hasil -0.03158566
#
# Iterasi ke- 3449 , suhu 0.02 derajat
# Solusi Terbaik : x1 = -0.19332459  ; x2 = -0.26515168  dengan hasil -0.02849398
#
# Iterasi ke- 3450 , suhu 0.02 derajat
# Solusi Terbaik : x1 = -0.21649970  ; x2 = -0.20057118  dengan hasil -0.03231120
#
# Iterasi ke- 3468 , suhu 0.01 derajat
# Solusi Terbaik : x1 = -0.35519740  ; x2 = -0.31959087  dengan hasil -0.03792309
#
# Iterasi ke- 3645 , suhu 0.01 derajat
# Solusi Terbaik : x1 = -0.35787642  ; x2 = -0.25966394  dengan hasil -0.04010178
#
# Iterasi ke- 3797 , suhu 0.00 derajat
# Solusi Terbaik : x1 = -0.31369798  ; x2 = -0.23858739  dengan hasil -0.04144072
#
# Iterasi ke- 4081 , suhu 0.00 derajat
# Solusi Terbaik : x1 = -0.31186800  ; x2 = -0.25844714  dengan hasil -0.04274486
#
# Iterasi ke- 4346 , suhu 0.00 derajat
# Solusi Terbaik : x1 = -0.31776654  ; x2 = -0.25032173  dengan hasil -0.04229439
#
# Iterasi ke- 4412 , suhu 0.00 derajat
# Solusi Terbaik : x1 = 0.30881022  ; x2 = 0.27306683  dengan hasil -0.04281112
# Iterasi ke- 8756 , suhu 0.00 derajat
# Solusi Terbaik : x1 = 0.32709574  ; x2 = 0.26934450  dengan hasil -0.04282265
#
# Iterasi ke- 10585 , suhu 0.00 derajat
# Solusi Terbaik : x1 = -0.32266533  ; x2 = -0.27840574  dengan hasil -0.04282939
# Iterasi ke- 19637 , suhu 0.00 derajat
# Solusi Terbaik : x1 = 0.31862543  ; x2 = 0.26457728  dengan hasil -0.04289041
#
# Iterasi ke- 30462 , suhu 0.00 derajat
# Solusi Terbaik : x1 = 0.31738613  ; x2 = 0.27402082  dengan hasil -0.04291922
# Iterasi ke- 46002 , suhu 0.00 derajat
# Solusi Terbaik : x1 = -0.31411298  ; x2 = -0.27022860  dengan hasil -0.04293335
